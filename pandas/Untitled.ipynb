# %%
import pandas as pd
data = pd.read_excel('Admin Panel.xlsx')
data
# Out:
#    Admin Panel            Unnamed: 1   Unnamed: 2      Unnamed: 3  \
# 0        SL NO             Date Time     Username  Origin Pincode
# 1            1  Apr 01,2022 11:04:23  FCB00000142          743127
# 2            2  Mar 31,2022 22:03:42  FCB00000160          743503
# 3            3  Mar 31,2022 22:03:20  FCB00000133          743127
# 4            4  Mar 31,2022 12:03:33  FCB00000032          700050
# 5            5  Mar 31,2022 10:03:24  FCB00000032          700050
# 6            6  Mar 30,2022 11:03:33  FCB00000114          721144
# 7            7  Mar 29,2022 13:03:54  FCB00000114          721144
# 8            8  Mar 29,2022 12:03:34  FCB00000032          700050
# 9            9  Mar 28,2022 14:03:35  FCB00000097          741123
# 10          10  Mar 28,2022 12:03:01  FCB00000131          700125
# 11          11  Mar 26,2022 16:03:18  FCB00000114          721144
# 12          12  Mar 22,2022 16:03:43  FCB00000097          741124
# ...
